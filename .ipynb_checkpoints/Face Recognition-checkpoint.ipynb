# %%
# TensorFlow and tf.keras
from __future__ import print_function

import tensorflow as tf
from tensorflow import keras
import glob
import numpy as np
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import matplotlib.pyplot as plt

import cv2 as cv
import argparse
import easydict
import time

# %%
allpersons = ["hakkani","mosarrof","tomo","maruf","nobo","arjun","nogami","arif","saidur"]

# %%
print(allpersons.index("saidur"))
# Out:
# 8

# %%
imagep = glob.glob("./images/*.jpg");
darray = [[0,""]];
#print(imagep)
for i in imagep:
    for j in allpersons:
        if i.find(j) != -1:
            #print(j+":"+i+"\n")
            darray = np.append(darray,[[j,i]], axis=0)

darray = np.delete(darray, 0, 0)
print(darray)
# Out:
# [['hakkani' './hakkani4.jpg']
#  ['mosarrof' './mosarrof15.jpg']
#  ['tomo' './tomo11.jpg']
#  ['maruf' './maruf2.jpg']
#  ['nobo' './nobo4.jpg']
#  ['tomo' './tomo10.jpg']
#  ['arjun' './arjun18.jpg']
#  ['tomo' './tomo22.jpg']
#  ['tomo' './tomo24.jpg']
#  ['maruf' './maruf4.jpg']
#  ['mosarrof' './mosarrof9.jpg']
#  ['nogami' './nogami1.jpg']
#  ['hakkani' './hakkani9.jpg']
#  ['hakkani' './hakkani16.jpg']
#  ['saidur' './saidur15.jpg']
#  ['nobo' './nobo20.jpg']
#  ['hakkani' './hakkani15.jpg']
#  ['mosarrof' './mosarrof23.jpg']
#  ['hakkani' './hakkani2.jpg']
#  ['arjun' './arjun10.jpg']
#  ['nobo' './nobo2.jpg']
#  ['arjun' './arjun2.jpg']
#  ['maruf' './maruf15.jpg']
#  ['nobo' './nobo15.jpg']
#  ['arjun' './arjun5.jpg']
#  ['hakkani' './hakkani13.jpg']
#  ['saidur' './saidur17.jpg']
#  ['arif' './arif2.jpg']
#  ['saidur' './saidur4.jpg']
#  ['nobo' './nobo10.jpg']
#  ['arif' './arif1.jpg']
#  ['maruf' './maruf17.jpg']
#  ['arjun' './arjun4.jpg']
#  ['saidur' './saidur6.jpg']
#  ['hakkani' './hakkani8.jpg']
#  ['saidur' './saidur2.jpg']
#  ['saidur' './saidur18.jpg']
#  ['mosarrof' './mosarrof3.jpg']
#  ['saidur' './saidur5.jpg']
#  ['maruf' './maruf16.jpg']
#  ['tomo' './tomo20.jpg']
#  ['maruf' './maruf9.jpg']
#  ['nobo' './nobo7.jpg']
#  ['hakkani' './hakkani6.jpg']
#  ['nogami' './nogami5.jpg']
#  ['maruf' './maruf6.jpg']
#  ['saidur' './saidur8.jpg']
#  ['tomo' './tomo5.jpg']
#  ['nobo' './nobo6.jpg']
#  ['tomo' './tomo8.jpg']
#  ['maruf' './maruf19.jpg']
#  ['hakkani' './hakkani11.jpg']
#  ['arjun' './arjun14.jpg']
#  ['maruf' './maruf18.jpg']
#  ['hakkani' './hakkani7.jpg']
#  ['mosarrof' './mosarrof25.jpg']
#  ['tomo' './tomo4.jpg']
#  ['mosarrof' './mosarrof13.jpg']
#  ['mosarrof' './mosarrof11.jpg']
#  ['tomo' './tomo14.jpg']
#  ['maruf' './maruf11.jpg']
#  ['arjun' './arjun19.jpg']
#  ['mosarrof' './mosarrof6.jpg']
#  ['nobo' './nobo17.jpg']
#  ['saidur' './saidur16.jpg']
#  ['tomo' './tomo17.jpg']
#  ['arjun' './arjun3.jpg']
#  ['tomo' './tomo6.jpg']
#  ['nobo' './nobo19.jpg']
#  ['saidur' './saidur1.jpg']
#  ['nobo' './nobo12.jpg']
#  ['tomo' './tomo7.jpg']
#  ['arjun' './arjun11.jpg']
#  ['arjun' './arjun6.jpg']
#  ['mosarrof' './mosarrof1.jpg']
#  ['nobo' './nobo14.jpg']
#  ['arjun' './arjun20.jpg']
#  ['nobo' './nobo11.jpg']
#  ['mosarrof' './mosarrof7.jpg']
#  ['tomo' './tomo9.jpg']
#  ['tomo' './tomo13.jpg']
#  ['nogami' './nogami7.jpg']
#  ['tomo' './tomo12.jpg']
#  ['arjun' './arjun21.jpg']
#  ['saidur' './saidur14.jpg']
#  ['maruf' './maruf14.jpg']
#  ['mosarrof' './mosarrof5.jpg']
#  ['mosarrof' './mosarrof12.jpg']
#  ['arjun' './arjun15.jpg']
#  ['mosarrof' './mosarrof22.jpg']
#  ['arjun' './arjun12.jpg']
#  ['nogami' './nogami4.jpg']
#  ['maruf' './maruf5.jpg']
#  ['arjun' './arjun17.jpg']
#  ['maruf' './maruf3.jpg']
#  ['mosarrof' './mosarrof17.jpg']
#  ['tomo' './tomo16.jpg']
#  ['nogami' './nogami6.jpg']
#  ['saidur' './saidur10.jpg']
#  ['nobo' './nobo16.jpg']
#  ['mosarrof' './mosarrof14.jpg']
#  ['hakkani' './hakkani10.jpg']
#  ['nobo' './nobo9.jpg']
#  ['mosarrof' './mosarrof24.jpg']
#  ['hakkani' './hakkani12.jpg']
#  ['hakkani' './hakkani3.jpg']
#  ['maruf' './maruf7.jpg']
#  ['maruf' './maruf8.jpg']
#  ['mosarrof' './mosarrof16.jpg']
#  ['hakkani' './hakkani5.jpg']
#  ['tomo' './tomo15.jpg']
#  ['maruf' './maruf13.jpg']
#  ['hakkani' './hakkani14.jpg']
#  ['hakkani' './hakkani17.jpg']
#  ['nobo' './nobo1.jpg']
#  ['mosarrof' './mosarrof8.jpg']
#  ['nobo' './nobo3.jpg']
#  ['saidur' './saidur11.jpg']
#  ['mosarrof' './mosarrof10.jpg']
#  ['tomo' './tomo3.jpg']
#  ['nobo' './nobo8.jpg']
#  ['tomo' './tomo1.jpg']
#  ['nobo' './nobo18.jpg']
#  ['arjun' './arjun9.jpg']
#  ['nogami' './nogami2.jpg']
#  ['saidur' './saidur7.jpg']
#  ['mosarrof' './mosarrof19.jpg']
#  ['mosarrof' './mosarrof21.jpg']
#  ['saidur' './saidur13.jpg']
#  ['hakkani' './hakkani18.jpg']
#  ['nobo' './nobo13.jpg']
#  ['tomo' './tomo18.jpg']
#  ['tomo' './tomo19.jpg']
#  ['mosarrof' './mosarrof20.jpg']
#  ['arjun' './arjun8.jpg']
#  ['nogami' './nogami3.jpg']
#  ['maruf' './maruf1.jpg']
#  ['saidur' './saidur9.jpg']
#  ['arjun' './arjun13.jpg']
#  ['tomo' './tomo23.jpg']
#  ['nobo' './nobo5.jpg']
#  ['maruf' './maruf10.jpg']
#  ['maruf' './maruf12.jpg']
#  ['arjun' './arjun1.jpg']
#  ['arjun' './arjun7.jpg']
#  ['tomo' './tomo21.jpg']
#  ['saidur' './saidur3.jpg']
#  ['arjun' './arjun16.jpg']
#  ['hakkani' './hakkani1.jpg']
#  ['tomo' './tomo2.jpg']
#  ['mosarrof' './mosarrof4.jpg']
#  ['mosarrof' './mosarrof18.jpg']
#  ['mosarrof' './mosarrof2.jpg']]

# %%
plt.figure(figsize=(25,40))
i=0
collected_image_data = []
train_lebel = []
for f in darray:
    #print(f[1])
    img = load_img(f[1], grayscale=False, color_mode='rgb', target_size=(28,28))
    # convert to numpy array
    img_array = img_to_array(img)

    img_array1 = img_array[:,:,1]
    img_array1 = img_array1/255
    collected_image_data.append(img_array1)
    plt.subplot(20,10,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(img_array1)
    plt.xlabel(f[0])
    train_lebel.append(allpersons.index(f[0]))
    i+=1
    
train_images = np.array(collected_image_data)
train_lebels = np.array(train_lebel)
plt.show()

# %%
#print(train_images[0])
print(train_lebel)
# Out:
# [0, 1, 2, 3, 4, 2, 5, 2, 2, 3, 1, 6, 0, 0, 8, 4, 0, 1, 0, 5, 4, 5, 3, 4, 5, 0, 8, 7, 8, 4, 7, 3, 5, 8, 0, 8, 8, 1, 8, 3, 2, 3, 4, 0, 6, 3, 8, 2, 4, 2, 3, 0, 5, 3, 0, 1, 2, 1, 1, 2, 3, 5, 1, 4, 8, 2, 5, 2, 4, 8, 4, 2, 5, 5, 1, 4, 5, 4, 1, 2, 2, 6, 2, 5, 8, 3, 1, 1, 5, 1, 5, 6, 3, 5, 3, 1, 2, 6, 8, 4, 1, 0, 4, 1, 0, 0, 3, 3, 1, 0, 2, 3, 0, 0, 4, 1, 4, 8, 1, 2, 4, 2, 4, 5, 6, 8, 1, 1, 8, 0, 4, 2, 2, 1, 5, 6, 3, 8, 5, 2, 4, 3, 3, 5, 5, 2, 8, 5, 0, 2, 1, 1, 1]

# %%
print(train_images.shape)
print(train_lebel)
# Out:
# (153, 28, 28)
# [0, 1, 2, 3, 4, 2, 5, 2, 2, 3, 1, 6, 0, 0, 8, 4, 0, 1, 0, 5, 4, 5, 3, 4, 5, 0, 8, 7, 8, 4, 7, 3, 5, 8, 0, 8, 8, 1, 8, 3, 2, 3, 4, 0, 6, 3, 8, 2, 4, 2, 3, 0, 5, 3, 0, 1, 2, 1, 1, 2, 3, 5, 1, 4, 8, 2, 5, 2, 4, 8, 4, 2, 5, 5, 1, 4, 5, 4, 1, 2, 2, 6, 2, 5, 8, 3, 1, 1, 5, 1, 5, 6, 3, 5, 3, 1, 2, 6, 8, 4, 1, 0, 4, 1, 0, 0, 3, 3, 1, 0, 2, 3, 0, 0, 4, 1, 4, 8, 1, 2, 4, 2, 4, 5, 6, 8, 1, 1, 8, 0, 4, 2, 2, 1, 5, 6, 3, 8, 5, 2, 4, 3, 3, 5, 5, 2, 8, 5, 0, 2, 1, 1, 1]

# %%
#Sequential model preparing
digit_model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10)
])

# %%
#compiling the model
digit_model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
#training the model with train data
digit_model.fit(train_images, train_lebels, epochs=10)
# Out:
# Epoch 1/10
# 5/5 [==============================] - 0s 957us/step - loss: 0.8302 - accuracy: 0.8758
# Epoch 2/10
# 5/5 [==============================] - 0s 847us/step - loss: 0.7617 - accuracy: 0.9085
# Epoch 3/10
# 5/5 [==============================] - 0s 840us/step - loss: 0.6917 - accuracy: 0.9020
# Epoch 4/10
# 5/5 [==============================] - 0s 967us/step - loss: 0.6402 - accuracy: 0.9281
# Epoch 5/10
# 5/5 [==============================] - 0s 769us/step - loss: 0.5859 - accuracy: 0.9150
# Epoch 6/10
# 5/5 [==============================] - 0s 846us/step - loss: 0.5379 - accuracy: 0.9216
# Epoch 7/10
# 5/5 [==============================] - 0s 1ms/step - loss: 0.4957 - accuracy: 0.9346
# Epoch 8/10
# 5/5 [==============================] - 0s 868us/step - loss: 0.4562 - accuracy: 0.9412
# Epoch 9/10
# 5/5 [==============================] - 0s 820us/step - loss: 0.4200 - accuracy: 0.9281
# Epoch 10/10
# 5/5 [==============================] - 0s 904us/step - loss: 0.3828 - accuracy: 0.9608

# %%
#probability model prepare from trained digit model 
probability_model = tf.keras.Sequential([digit_model, 
                                         tf.keras.layers.Softmax()])

# %%
#prediction from test data
predictions = probability_model.predict(test_data)

# %%
def detectAndDisplay(frame):
    frame_gray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)
    frame_gray = cv.equalizeHist(frame_gray)

    #-- Detect faces
    faces = face_cascade.detectMultiScale(frame_gray)
    count = 0
    for (x,y,w,h) in faces:
        crop_img = frame[y:y+h, x:x+w]
        #cv.imwrite("frame%d.jpg" % round(time.time()), crop_img)     # save frame as JPEG file 
        #predictions = probability_model.predict(test_data)
        crop_img1 = cv.resize(crop_img, (28, 28))
        img_array1 = crop_img1[:,:,1]
        img_array1 = img_array1/255
        
        img1 = (np.expand_dims(img_array1,0))
        predictions_single = probability_model.predict(img1)
        
        print(allpersons[np.argmax(predictions_single[0])])
        
        print(img_array1.shape)
        plt.figure(figsize=(5,5))
        plt.imshow(img_array1)
        plt.colorbar()
        plt.grid(False)
        plt.show()
        
        print(crop_img1.shape)
        count += 1
        center = (x + w//2, y + h//2)
        frame = cv.ellipse(frame, center, (w//2, h//2), 0, 0, 360, (255, 0, 255), 4)
        frame = cv.rectangle(frame, (x,y), (x+w,y+h), (255, 255, 0), 4)
        
        

        faceROI = frame_gray[y:y+h,x:x+w]
        #-- In each face, detect eyes
        eyes = eyes_cascade.detectMultiScale(faceROI)
        for (x2,y2,w2,h2) in eyes:
            eye_center = (x + x2 + w2//2, y + y2 + h2//2)
            radius = int(round((w2 + h2)*0.25))
            frame = cv.circle(frame, eye_center, radius, (255, 0, 0 ), 4)

    cv.imshow('Capture - Face detection', frame)

# %%
args = easydict.EasyDict({
        "face_cascade": 'data/haarcascade_frontalface_alt.xml',
        "eyes_cascade": 'data/haarcascade_eye_tree_eyeglasses.xml',
        "camera": 0
})
face_cascade_name = args.face_cascade
eyes_cascade_name = args.eyes_cascade
face_cascade = cv.CascadeClassifier()
eyes_cascade = cv.CascadeClassifier()

#-- 1. Load the cascades
if not face_cascade.load('/home/ai-lab1/.local/lib/python3.6/site-packages/cv2/'+face_cascade_name):
    print('--(!)Error loading face cascade')
    exit(0)
if not eyes_cascade.load('/home/ai-lab1/.local/lib/python3.6/site-packages/cv2/'+eyes_cascade_name):
    print('--(!)Error loading eyes cascade')
    exit(0)
    
camera_device = args.camera
#-- 2. Read the video stream
cap = cv.VideoCapture(camera_device)

if not cap.isOpened:
    print('--(!)Error opening video capture')
    exit(0)

# %%
while True:
    ret, frame = cap.read()
    if frame is None:
        print('--(!) No captured frame -- Break!')
        break

    detectAndDisplay(frame)   
    if cv.waitKey(10) == 27:
        break
# Out:
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# tomo
# (28, 28)
# (28, 28, 3)
# hakkani
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# hakkani
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# hakkani
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# hakkani
# (28, 28)
# (28, 28, 3)
# hakkani
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# hakkani
# (28, 28)
# (28, 28, 3)
# hakkani
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# hakkani
# (28, 28)
# (28, 28, 3)
# hakkani
# (28, 28)
# (28, 28, 3)
# hakkani
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# hakkani
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# nobo
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# maruf
# (28, 28)
# (28, 28, 3)
# tomo
# (28, 28)
# (28, 28, 3)
# tomo
# (28, 28)
# (28, 28, 3)
# tomo
# (28, 28)
# (28, 28, 3)
# tomo
# (28, 28)
# (28, 28, 3)
# tomo
# (28, 28)
# (28, 28, 3)
